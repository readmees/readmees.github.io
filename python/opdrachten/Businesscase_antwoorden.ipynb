# %% [markdown]
# # Businesscase
# We hebben het gehaald tot de businesscase! In deze opdracht gaan we met Python een e-mail versturen. Let wel op dat dit niet een veilige manier van inloggen en versturen is en dat het daarom belangrijk is dit te doen met het Gmail account dat je, speciaal voor deze cursus, hebt aangemaakt.
#
# Het is leuk om hier je eigen werk van te maken. De opdracht begeleid je alleen in het versturen van een mail. Leuke bonussen:
#
#
# *   Stuur de mail naar meerdere adressen met een for-loop
# *   Gebruik variabellen in het bericht
# *   Verander de aanhef zodat ie werkt met meerdere namen

# %%
# Benodigde libraries importeren
from email.message import EmailMessage

#TODO: importeer smtplib en ssl
import smtplib, ssl

# %%
def send_mail(sender, password, msg):
    '''Dit stukje code verstuurd een email vanaf je gmail account
    Dit hoef je niet te begrijpen en heb ik zelf ook van internet gehaald'''

    context = ssl.create_default_context()
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls(context=context)
        server.login(sender, password)
        server.send_message(msg)

# %%
#TODO: Vul hier je Gmail in die je voor deze cursus hebt aangemaakt
sender = "pythonbasistest@gmail.com"

#TODO: Vul mijn mail in: "mm@opatel.nl"
receiver = "mm@opatel.nl"

#TODO: Vraag het app wachtwoord in input
# Dit kan je aanmaken in: https://myaccount.google.com/apppasswords
password = input('Wat is je wachtwoord?')

#TODO: Pas je het bericht aan
message = EmailMessage()
message.set_content("This is a test email sent from Python.")
message["Subject"] = "Test Email"
message["From"] = sender
message["To"] = receiver


#TODO: Roep de functie aan met parameters
send_mail(sender, password, message)
print("Email sent")
# Out:
# Wat is je wachtwoord?intp fsqe wsud ohlf
# Email sent
