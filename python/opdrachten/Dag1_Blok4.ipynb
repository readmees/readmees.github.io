# %%
''' Deze code mag je negeren en hoef je niet te begrijpen; het is om je te helpen met checks en tips'''
def tip(index, items=['Let op de typo in de functienaam (squaed moet squared zijn). De parameter b wordt niet gebruikt; in plaats daarvan wordt er geprobeerd a te gebruiken, wat niet gedefinieerd is. Gebruik b in de berekening.', 'return a plus a', 'Voor elke TODO, vervang None met de juiste vergelijking die de beschrijving volgt.', 'Deze is correct, nu kan je Mees vervangen voor je eigen naam.', 'Verander de voorwaarde zodat het controleert of my_name gelijk is aan je eigen naam.', 'De functie moet het argument x nemen en x + 1 retourneren.', 'Er zitten 365 dagen in een jaar.', 'Controleer of index negatief is of groter dan de lengte van de lijst minus één (omdat indexering bij 0 begint).', 'De if-controle komt na een return-statement, wat betekent dat het nooit bereikt zal worden. Zet de if-controle boven de eerste return-statement. Zorg daarnaast dat de input-functie correct wordt gebruikt en de waarde naar de begroeting-functie wordt doorgegeven.', "Gebruik een set om te controleren of alle elementen in de lijst resultaat hetzelfde zijn. Als de lengte van de set 1 is, retourneer '€100!'; anders, 'Verloren'."]): return f'Hier is je tip voor vraag {index}: \n' + items[index-1] if type(index) == int and 1 <= index < len(items) + 1 else 'Er is geen tip voor deze opdracht'
def check(input, help): return 'Goed: je antwoord klopt volgens deze check' if input else help.replace('Fout:', 'Het antwoord klopt nog niet helemaal:')

# %%
''' Opdracht 1: Debug de squared functie: los de errors op '''
def squaed(b): # Jouw antwoord
    return a * a # Jouw antwoord

print(squared(4))

print(check(squared(4) == 16, "Fout: squared(4) komt niet overeen met 16"))
print(check(squared(4) == 16, "Fout: squared(4) komt niet overeen met 16"))

# %%
''' Opdracht 2: Schrijf met behulp van de funtie hierboven een functie die de som neemt van twee getallen en dat returned.'''
def som(getal1, getal2):
    return None # Jouw antwoord

print(1, 2)

# %%
''' Opdracht 3: Schrijf code in de volgende velden.'''
# Print 5 kleiner dan 6
print(5 < 6)

# TODO: Print 2 groter dan 10
None # Jouw antwoord
# TODO: Print 8 gelijk aan 8
None # Jouw antwoord
# TODO: Print 5 is niet 10
None # Jouw antwoord
# TODO: Print 5 kleiner dan 10
None # Jouw antwoord
# TODO: Print 5 kleiner dan of gelijk aan 5
None # Jouw antwoord
# TODO: Print 5 groter dan of gelijk aan 3
None # Jouw antwoord
# TODO: Print 5 groter dan of gelijk aan 5
None # Jouw antwoord

# %%
''' Opdracht 4: Boolean vergelijkingen hoeven niet alleen met cijfers, verander zodat het werkt met je eigen naam.'''
print('Mees' == 'Mees')  # Jouw antwoord

# %%
''' Opdracht 5: Boolean vergelijkingen kunnen ook uitgebreid worden, verander zodat het werkt met je eigen naam.'''
my_name = 'Chantal'  # Jouw antwoord
if my_name == 'Mees':  # Jouw antwoord
    print('Dit is mijn naam')
else:
    print('Dit is niet mijn naam')

# %%
''' Opdracht 6: Schrijf een functie die het volgende getal geeft. '''
def volgende(x):
    None # Jouw antwoord

print(volgende(8)) # Hier zou 9 uit moeten komen
print(volgende(-8)) # Hier zou -7 uit moeten komen

print(check(volgende(109921) == 109922, "Fout: de functie werkt nog niet voor getal 109921"))
print(check(volgende(-109921) == -109920, "Fout: de functie werkt nog niet voor getal -109921"))
# Out:
# 9
# -7
# 'Goed: je antwoord klopt volgens deze check'

# %%
''' Opdracht 7: Schrijf een functie die je leeftijd omzet naar dagen (je hoeft geen rekening te houden met schrikkeljaren). '''
def leeftijd_naar_dagen(int_of_float):
    # TODO: maak functie af

# Roep je functie aan met input van de gebruiker
leeftijd_in_jaar = input("Voer je leeftijd in jaar: ")
print(leeftijd_naar_dagen(int(leeftijd_in_jaar)))

check(leeftijd_naar_dagen(20) == 7300, "Fout: de functie werkt nog niet voor 20")

# %%
''' Opdracht 8: Schrijf een functie dat een lijst en een index als input neemt het element op de index returned.
        Zorg dat de functie foutmeldingen returned als de index negatief, een float, of groter dan de
        lijst lang is.
        Tip: de lengte van een lijst kan gevonden worden met len(lijst), dus index mag niet groter zijn dan len(lijst)'''
def lijst_helper(lijst, index):
    if index < None: # Jouw antwoord
        return 'De index is negatief'
    if index > None: # Jouw antwoord
        return 'De index is te hoog'
    return lijst[index]

print(lijst_helper([3,21,4,4], 400)) # Hier zou een foutmelding moeten komen 'De index is te hoog'
print(lijst_helper([3,21,4,4], -100)) # Hier zou een foutmelding moeten komen 'De index is te hoog'
# Out:
# De index is te hoog
# De index is negatief

# %%
''' Opdracht 9: Debug de code hieronder. '''
def begroeting(cursist):
    return "U bent hier geen cursist"
    if opleiding == "ja":
        return "U bent hier cursist"
input('Bent u cursist?')
begroeting(cursist)

# %%
''' Opdracht 10: Jackpot - return '€100!' als alle 4 iconen gelijk zijn, anders return 'Verloren'. '''
def jackpot(resultaat):
    return '€100!'

print(jackpot(["@", "@", "@", "@"])) # Hier zou '€100!' uit moeten komen
print(jackpot(["abc", "abc", "abc", "abc"])) # Hier zou '€100!' uit moeten komen
print(jackpot(["SS", "SS", "SS", "SS"])) # Hier zou '€100!' uit moeten komen
print(jackpot(["&&", "&", "&&&", "&&&&"])) # Hier zou 'Verloren' uit moeten komen
print(jackpot(["SS", "SS", "SS", "Ss"])) # Hier zou 'Verloren' uit moeten komen

print(check(jackpot(["SS", "SS", "abc", "SS"]) == 'Verloren', 'Fout: ["SS", "SS", "abc", "SS"] zou \'Verloren\' moeten geven'))
print(check(jackpot(["SS", "SS", "SS", "SS"]) == '€100!', 'Fout: ["SS", "SS", "SS", "SS"] zou \'€100!\' moeten geven'))
# Out:
# €100!
# €100!
# €100!
# €100!
# €100!
# Het antwoord klopt nog niet helemaal: ["SS", "SS", "abc", "SS"] zou 'Verloren' moeten geven
# Goed: je antwoord klopt volgens deze check

# %%
''' Snel klaar? Probeer deze opdrachten uit.
    Bonus 1: Je kan de jackpot verder uitbreiden door verschillende prijzen bij bepaalde combinaties te returnen
    Bonus 2: Je kan de onderwerpen herhalen en verder oefenen op https://www.w3schools.com/python/default.asp.
    Bonus 3: Je kan op https://edabit.com kijken voor meer opdrachten.'''
