# %%
def tip(index, items=['Strings kunnen direct worden toegewezen met behulp van aanhalingstekens.', 'Gebruik de len() functie om de lengte van een string te vinden.', 'Gebruik slicing met tekst[startindex:eindindex] om een substring te slicen, bijvoorbeeld tekst[4:] om vanaf letter de 5e letter tot het einde te pakken.', 'Gebruik het + teken om strings aan elkaar te plakken.', 'Gebruik de .upper() methode om een string om te zetten naar hoofdletters.', 'Gebruik de .lower() methode om een string om te zetten naar kleine letters.', 'Gebruik de type() functie om het type van een variabele te controleren.', 'Een geheel getal en kommagetal worden door Python als integer en float toegewezen.', 'Gebruik + om getallen op te tellen.', 'Gebruik een vergelijking met > om te controleren of een waarde groter is.', 'Gebruik de .title() methode om elk woord in een string te beginnen met een hoofdletter.', 'Gebruik de .upper() methode om alle letters in een string naar hoofdletters te converteren.', 'Gebruik de .replace(oud, nieuw) methode om een deel van de string te vervangen.', 'Gebruik de .strip() methode om witruimte aan het begin en einde van een string te verwijderen.', 'Gebruik de .split(delimiter) methode om een string te splitsen in een lijst van substrings.']): return f'Hier is je tip voor vraag {index}: \n' + items[index-1] if type(index) == int and 1 <= index < len(items) + 1 else 'Er is geen tip voor deze opdracht'
def check(input, help): return 'Goed: je antwoord klopt volgens deze check' if input else help.replace('Fout:', 'Het antwoord klopt nog niet helemaal:')

# %%
''' Opdracht 1: Strings manipuleren '''
# TODO: Maak een string variabele genaamd `tekst` met de waarde "Hallo Python".
tekst = None # Jouw antwoord
 
check(tekst == "Hallo Python", "Fout: de tekst is niet correct")

# %%
''' Opdracht 2: String lengte '''
# TODO: Bepaal de lengte van de string `tekst` en sla deze op in een variabele genaamd `lengte`.
tekst = "Hallo Python"
lengte = None # Jouw antwoord
 
check(lengte == 12, "Fout: de lengte van de tekst is niet correct")

# %%
''' Opdracht 3: String slicen '''
# TODO: Haal de substring "Python" uit de variabele `tekst` en sla deze op in een nieuwe variabele `substring`.
tekst = "Hallo Python"
substring = None # Jouw antwoord
 
check(substring == "Python", "Fout: de substring is niet correct")

# %%
''' Opdracht 4: Strings samenvoegen '''
# TODO: Voeg de string " is leuk!" toe aan `tekst` en sla het resultaat op in een variabele genaamd `nieuwe_tekst`.
tekst = "Hallo Python"
nieuwe_tekst = None # Jouw antwoord
 
check(nieuwe_tekst == "Hallo Python is leuk!", "Fout: de nieuwe tekst is niet correct")

# %%
''' Opdracht 5: String omzetten naar hoofdletters '''
# TODO: Zet de string `tekst` om naar hoofdletters en sla het resultaat op in een variabele genaamd `hoofdletters`.
tekst = "Hallo Python"
hoofdletters = None # Jouw antwoord
 
check(hoofdletters == "HALLO PYTHON", "Fout: de tekst is niet in hoofdletters")

# %%
''' Opdracht 6: String omzetten naar kleine letters '''
# TODO: Zet de string `tekst` om naar kleine letters en sla het resultaat op in een variabele genaamd `kleine_letters`.
tekst = "Hallo Python"
kleine_letters = None # Jouw antwoord
 
check(kleine_letters == "hallo python", "Fout: de tekst is niet in kleine letters")

# %%
''' Opdracht 7: Type controleren '''
# TODO: Controleer het type van de variabele `tekst` en sla het resultaat op in een variabele genaamd `type_var`.
tekst = "Hallo Python"
type_var = None # Jouw antwoord
 
check(type_var == str, "Fout: het type van de variabele is niet str")

# %%
''' Opdracht 8: Integer en Floats '''
# TODO: Maak twee variabelen, `int_var` en `float_var`, en wijs een geheel getal en een kommagetal toe.
int_var = None # Jouw antwoord
float_var = None # Jouw antwoord
 
check(int_var == 10 and float_var == 20.5, "Fout: de waarden van de variabelen zijn niet correct")

# %%
''' Opdracht 9: Rekenen met integers en floats '''
# TODO: Tel `int_var` en `float_var` op en sla het resultaat op in een variabele genaamd `som`.
int_var = 10
float_var = 20.5
som = None # Jouw antwoord
 
check(som == 30.5, "Fout: de som is niet correct")

# %%
''' Opdracht 10: Boolean waarden '''
# TODO: Maak een variabele genaamd `waarheid` en wijs de waarde True toe als `int_var` groter is dan 5, anders False.
int_var = 10
waarheid = None # Jouw antwoord
 
check(waarheid == True, "Fout: de waarheidswaarde is niet correct")

# %%
''' Opdracht 11: Eerste letter van elk woord naar hoofdletter '''
# TODO: Zet de eerste letter van elk woord in de string `tekst` naar een hoofdletter en sla het resultaat op in een variabele genaamd `titel_tekst`.
tekst = "hallo python programmeurs"
titel_tekst = None # Jouw antwoord
 
check(titel_tekst == "Hallo Python Programmeurs", "Fout: de tekst is niet correct geformatteerd")

# %%
''' Opdracht 12: Volledige tekst naar hoofdletters '''
# TODO: Zet de volledige tekst `tekst` om naar hoofdletters en sla het resultaat op in een variabele genaamd `schreeuw_tekst`.
tekst = "ik ben aan het leren programmeren"
schreeuw_tekst = None # Jouw antwoord
 
check(schreeuw_tekst == "IK BEN AAN HET LEREN PROGRAMMEREN", "Fout: de tekst is niet volledig in hoofdletters")

# %%
''' Opdracht 13: Tekst vervangen '''
# TODO: Vervang het woord "Python" door "Py" in de string `tekst` en sla het resultaat op in een variabele genaamd `korte_tekst`.
tekst = "Hallo Python programmeurs"
korte_tekst = None # Jouw antwoord
 
check(korte_tekst == "Hallo Py programmeurs", "Fout: de tekst is niet correct aangepast")

# %%
''' Opdracht 14: Karakters verwijderen '''
# TODO: Verwijder de spaties aan het begin en einde van `tekst` en sla het resultaat op in een variabele genaamd `gestripte_tekst`.
tekst = "   Hallo Python!   "
gestripte_tekst = None # Jouw antwoord
 
check(gestripte_tekst == "Hallo Python!", "Fout: de tekst is niet correct gestript")

# %%
''' Opdracht 15: Karakter splitsen '''
# TODO: Splits de string `tekst` bij elke spatie en sla het resultaat op in een variabele genaamd `woorden_lijst`.
tekst = "Hallo Python programmeurs"
woorden_lijst = None # Jouw antwoord
 
check(woorden_lijst == ["Hallo", "Python", "programmeurs"], "Fout: de tekst is niet correct gesplitst")
