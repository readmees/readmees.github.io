# %%
''' Deze code mag je negeren en hoef je niet te begrijpen; het is om je te helpen met checks en tips'''
def tip(index, items=['Gebruik het = teken om een waarde aan een variabele toe te wijzen.', 'Gebruik + om twee variabelen op te tellen.', 'Gebruik - om een getal van een ander af te trekken.', 'Gebruik * om twee getallen te vermenigvuldigen.', 'Gebruik / en // voor delingen.', 'Gebruik % om de restwaarde van een deling te vinden.', 'Gebruik input() om gebruikersinput te vragen.', 'Gebruik print() om een waarde te tonen.', 'Gebruik t = type(x)', 'Gebruik str(), int(), float() om te converteren.', 'Gebruik .upper() en .lower() voor tekstbewerking.', 'Gebruik len() om de lengte van een string te bepalen.', 'Gebruik [] om te slicen in strings.', 'Gebruik [] om elementen uit een lijst te halen.', 'Gebruik append() om een element aan een lijst toe te voegen.', 'Gebruik {"key1": "value1", "key2":"value2"} om een dictionary te maken.', 'Gebruik set() om dubbele waarden te verwijderen.', 'Gebruik def functie_naam(...): om een functie te maken.', 'Gebruik if/elif/else voor control flow.', 'Gebruik return om een waarde terug te geven uit een functie.', 'Gebruik kleiner_of_gelijk = a <= b (a is kleiner of gelijk aan b)', 'Gebruik <, >, <=, >= voor vergelijkingen.', 'Gebruik and en or om logica te combineren.', 'Gebruik f-strings of + om tekst samen te voegen.', 'Gebruik isinstance(x, str/int/float) om types te testen.']): return f'Hier is je tip voor vraag {index}: \n' + items[index-1] if isinstance(index, int) and 1 <= index <= len(items) else 'Er is geen tip voor deze opdracht'
def check(result, help_text): return 'Goed: je antwoord klopt volgens deze check' if result else help_text.replace('Fout:', 'Het antwoord klopt nog niet helemaal:')

# %% [markdown]
# # Blok 2 – Programmeren in Python

# %%
''' Opdracht 1: Variabelen toewijzen '''
# TODO: Maak een variabele a met waarde 10.
a = None  # Jouw antwoord

print(tip(1))
check(a == 10, 'Fout: a heeft niet de waarde 10')
# Out:
# Hier is je tip voor vraag 1:
# Gebruik het = teken om een waarde aan een variabele toe te wijzen.
# 'Het antwoord klopt nog niet helemaal: a heeft niet de waarde 10'

# %%
''' Opdracht 2: Twee getallen optellen '''
# TODO: Maak variabelen x=5 en y=7 en tel ze op in z.
x = None  # Jouw antwoord
y = None  # Jouw antwoord
z = None  # Jouw antwoord

print(tip(2))
check(z == 12, 'Fout: z is niet gelijk aan 12')

# %%
''' Opdracht 3: Input verwerken '''
# TODO: Vraag de gebruiker welke dag het is en sla dit op in dag.
# Gebruik input('Welke dag is het? ').
dag = None  # Jouw antwoord

print(tip(7))
check(isinstance(dag, str) or dag is None, 'Fout: dag zou tekst moeten zijn')

# %%
''' Opdracht 4: Output genereren '''
# TODO: Print de zin: Vandaag is het <dag>.
# Gebruik de variabele dag uit opdracht 3.
None  # Jouw print-opdracht

# %%
''' Opdracht 5: Rekenen met variabelen '''
b = 20
c = 6
# TODO: Gebruik *, // en % in drie aparte variabelen.
product = None       # b keer c
vloerdeling = None   # b // c
rest = None          # b % c

print(tip(4))
check(product == 120 and vloerdeling == 3 and rest == 2,
      'Fout: een of meer berekeningen zijn niet correct')

# %% [markdown]
# # Blok 3a – Data Types Individueel

# %%
''' Opdracht 6: Type controleren '''
x = 5.5
# TODO: Sla het type van x op in t.
t = None  # Jouw antwoord

print(tip(9))
check(t == float, 'Fout: type is niet float')
# Out:
# Hier is je tip voor vraag 9:
# Gebruik t = type()
# 'Het antwoord klopt nog niet helemaal: type is niet float'

# %%
''' Opdracht 7: Strings bewerken '''
tekst = 'python programmeren'
# TODO: Zet tekst om naar hoofdletters in hoofd en naar kleine letters in klein.
hoofd = None  # Jouw antwoord
klein = None  # Jouw antwoord

print(tip(11))
check(hoofd == 'PYTHON PROGRAMMEREN' and klein == 'python programmeren',
      'Fout: tekstconversie is incorrect')

# %%
''' Opdracht 8: String slicing '''
zin = 'Hallo Python!'
# TODO: Slice 'Python' uit zin en sla dit op in deel.
deel = None  # Jouw antwoord

print(tip(13))
check(deel == 'Python', 'Fout: slicing klopt niet')

# %%
''' Opdracht 9: Boolean vergelijken '''
a = 10
b = 3
# TODO: Maak variabelen groter en kleiner_of_gelijk met booleans.
groter = None             # True als a > b
kleiner_of_gelijk = None  # True als a <= b

print(tip(21))
check(groter is True and isinstance(kleiner_of_gelijk, bool), 'Fout: controleer je vergelijkingen nogmaals')
# Out:
# Hier is je tip voor vraag 21:
# Gebruik kleiner_of_gelijk = a <= b (a is kleiner of gelijk aan b)
# 'Het antwoord klopt nog niet helemaal: controleer je vergelijkingen nogmaals'

# %% [markdown]
# # Blok 3b – Data Types – Verzamelingen

# %%
''' Opdracht 10: Lijsten manipuleren '''
# TODO: Maak een lijst fruit met 'appel' en 'banaan' en voeg 'kers' toe.
fruit = None  # Jouw antwoord
None          # Voeg 'kers' toe met append()

print(tip(15))
check(fruit == ['appel', 'banaan', 'kers'], 'Fout: fruit-lijst is niet correct')

# %%
''' Opdracht 11: Dictionary maken '''
# TODO: Maak een dictionary persoon met sleutels 'naam' en 'leeftijd'.
persoon = None  # Jouw antwoord

print(tip(16))
check(isinstance(persoon, dict) and 'naam' in persoon and 'leeftijd' in persoon, 'Fout: dictionary mist gegevens')
# Out:
# Hier is je tip voor vraag 16:
# Gebruik sleutel: waarde om een dictionary te maken.
# 'Het antwoord klopt nog niet helemaal: dictionary mist gegevens'

# %%
''' Opdracht 12: Waarde lezen uit dictionary '''
persoon = {'naam': 'Jan', 'leeftijd': 30}
# TODO: Lees de naam uit persoon en sla dit op in naam.
naam = None  # Jouw antwoord

print(tip(16))
check(naam == 'Jan', 'Fout: de naam is niet correct opgehaald')

# %%
''' Opdracht 13: Sets gebruiken '''
# TODO: Maak een set cijfers met 1, 2, 3 en voeg 4 toe.
cijfers = None  # Jouw antwoord
None            # Voeg 4 toe met .add()

print(tip(17))
check(cijfers == {1, 2, 3, 4}, 'Fout: set bevat niet de juiste waarden')

# %%
''' BLOK 4 – Functies & Control Flow '''

# %%
''' Opdracht 14: Functie bouwen '''
# TODO: Schrijf een functie kwadraat(x) die x**2 returned.
def kwadraat(x):
    None  # Jouw code hier

print(tip(18))
check(kwadraat(5) == 25, 'Fout: kwadraat(5) is niet 25')

# %%
''' Opdracht 15: If-else '''
# TODO: Gebruik if-else om te printen of leeftijd >= 18.
leeftijd = 17
None  # Jouw if-else code hier
