# %%
''' Deze code mag je negeren en hoef je niet te begrijpen; het is om je te helpen met checks en tips'''
def tip(index, items=['Gebruik het = teken om een waarde aan een variabele toe te wijzen.', 'Gebruik + om twee variabelen op te tellen.', 'Gebruik - om een getal van een ander af te trekken.', 'Gebruik * om twee getallen te vermenigvuldigen.', 'Gebruik / voor delen.', 'Gebruik // voor vloerdeling.', 'Gebruik % om de restwaarde van een deling te vinden.', 'Gebruik ** om een getal tot een bepaalde macht te verheffen.', 'Gebruik input("Welke dag is het?") om gebruikersinput te krijgen.', 'Gebruik print() om een waarde te tonen.', 'Gebruik # voor een notitie van een enkele regel.', 'Gebruik + om strings samen te voegen.', 'Gebruik int() om een string naar een integer om te zetten.', 'Gebruik len() om de lengte van een string te bepalen.', 'Gebruik len() om de lengte van een string te bepalen.', 'Gebruik input() om gebruikersinput te vragen', 'Gebruik input() om gebruikersinput te vragen. Strings hoeven niet geconverteerd te worden.', 'Gebruik de code van opdracht 16.', 'Gebruik 2x de code van opdracht 16.', 'Gebruik "Hallo " + naam en print', 'Oppervlakte vierkant is lengte*breedte']): return f'Hier is je tip voor vraag {index}: \n' + items[index-1] if type(index) == int and 1 <= index < len(items) + 1 else 'Er is geen tip voor deze opdracht'
def check(input, help): return 'Goed: je antwoord klopt volgens deze check' if input else help.replace('Fout:', 'Het antwoord klopt nog niet helemaal:')

# %%
''' Opdracht 1: Variabelen toewijzen'''
# TODO: Maak een variabele genaamd `a` en wijs de waarde 5 toe.
a = None # De variabele a is nu nog niets

# Op deze manier laat je een tip zien (1 staat voor opdracht 1)
print(tip(1))

# Deze regel controleert of je antwoord goed is
check(a == 5, "Fout: de waarde van a is niet correct")
# Out:
# Hier is je tip voor vraag 1:
# Gebruik het = teken om een waarde aan een variabele toe te wijzen.
# 'Het antwoord klopt nog niet helemaal: de waarde van a is niet correct'

# %%
''' Opdracht 2: Variabelen optellen'''
# TODO: Maak twee variabelen, `b` en `c`, en wijs 10 en 20 toe.
# Tel deze daarna op en sla het resultaat op in een nieuwe variabele `d`.
b = None  # Jouw antwoord
c = None  # Jouw antwoord
d = None  # Jouw antwoord

# Je kan altijd vragen om een tip
print(tip(2))
check(d == 30, "Fout: de waarde van d is niet correct")
# Out:
# Hier is je tip voor vraag 2:
# Gebruik + om twee variabelen op te tellen.
# 'Het antwoord klopt nog niet helemaal: de waarde van d is niet correct'

# %%
''' Opdracht 3: Variabele aftrekken'''
# TODO: Trek 15 af van de variabele `d` en sla het resultaat op in een nieuwe variabele `e`.
# Vraag eventueel om een tip zoals in opdracht 1 & 2
e = None

check(e == 15, "Fout: de waarde van e is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van e is niet correct'

# %%
''' Opdracht 4: Variabelen vermenigvuldigen'''
# TODO: Vermenigvuldig variabele `b` met 3 en sla het resultaat op in variabele `f`.
f = None  # Jouw antwoord

check(f == 30, "Fout: de waarde van f is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van f is niet correct'

# %%
''' Opdracht 5: Variabelen delen'''
# TODO: Deel variabele `f` door 10 en sla het resultaat op in variabele `g`.
g = None # Jouw antwoord

check(g == 3, "Fout: de waarde van g is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van g is niet correct'

# %%
''' Opdracht 6: Vloerdeling'''
# TODO: Voer een vloerdeling uit met `f` en 4 en sla het resultaat op in `h`.
h = None  # Jouw antwoord

check(h == 7, "Fout: de waarde van h is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van h is niet correct'

# %%
''' Opdracht 7: Modulo'''
# TODO: Bereken de restwaarde van `f` gedeeld door 4 en sla dit op in `i`.
i = None  # Jouw antwoord

check(i == 2, "Fout: de waarde van i is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van i is niet correct'

# %%
''' Opdracht 8: Tot de macht'''
# TODO: Verhef `b` tot de macht 3 en sla het resultaat op in `j`.
j = None # Jouw antwoord

check(j == 1000, "Fout: de waarde van j is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van j is niet correct'

# %%
''' Opdracht 9: Input verwerken'''
# TODO: Vraag de gebruiker welke dag het is en sla het resultaat op in `dag`
dag = None

check(isinstance(dag, str), "Fout: dag is geen tekst")
# Out:
# 'Het antwoord klopt nog niet helemaal: dag is geen tekst'

# %%
''' Opdracht 10: Output genereren'''
# TODO: Print de waarde van variabele `dag`.
None # Jouw antwoord

# %%
''' Opdracht 11: Notitie toevoegen'''
# TODO: Voeg een notitie toe dat uitlegt wat variabele `l` doet. Maak `l` gelijk aan 100.
l = None  # Jouw antwoord

# %%
''' Opdracht 12: Strings samenvoegen'''
# TODO: Maak twee strings, `m` met de tekst "Hallo" en `n` met "Wereld". Voeg ze samen met een spatie ertussen en sla dit op in `o`.
m = None  # Jouw antwoord
n = None  # Jouw antwoord
o = None  # Jouw antwoord

check(o == "Hallo Wereld", "Fout: de waarde van o is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van o is niet correct'

# %%
''' Opdracht 13: String naar Integer'''
# TODO: Zet de string "123" om naar een integer en sla dit op in `p`.
s = "123"
p = None  # Jouw antwoord

check(p == 123, "Fout: de waarde van p is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van p is niet correct'

# %%
''' Opdracht 14: Lengte van een String'''
# TODO: Bepaal de lengte van de string "Python" en sla dit op in `q`.
q = None  # Jouw antwoord

check(q == 6, "Fout: de lengte van q is niet correct")
# Out:
# 'Het antwoord klopt nog niet helemaal: de lengte van q is niet correct'

# %%
''' Opdracht 15: String methoden'''
# TODO: Bepaal de lengte van een string van je naam en sla dit op in `lengte`.
lengte = None  # Jouw antwoord

check(type(lengte) == int, "Fout: de waarde van r is niet correct, het zou een getal moeten zijn")
# Out:
# 'Het antwoord klopt nog niet helemaal: de waarde van r is niet correct, het zou een getal moeten zijn'

# %%
''' Opdracht 16: Gebruik input om een getal te vragen'''
# TODO: Vraag de gebruiker om een getal en converteer dit naar een integer. Sla dit op in een variabele genaamd `getal`.
getal = None # Jouw antwoord

# De input wordt automatisch als tekst gezien, de volgende regel zet het om in een getal
getal = int(getal)

# %%
''' Opdracht 17: String input'''
# TODO: Vraag de gebruiker om hun naam en sla dit op in een variabele genaamd `naam`.
naam = None  # Jouw antwoord

check(isinstance(naam, str), "Fout: naam is geen string")
# Out:
# Wat is je naam? Mees
# 'Goed: je antwoord klopt volgens deze check'

# %%
''' Opdracht 18: Input en print combinatie'''
# TODO: Vraag de gebruiker om hun leeftijd en print een bericht dat zegt "Je bent [leeftijd] jaar oud."
leeftijd = None  # Jouw antwoord

# Hier gebruiken we komma's om het getal met de text samen te voegen
print("Je bent", leeftijd, "jaar oud.")

# %%
''' Opdracht 19: Rekenen met input'''
# TODO: Vraag de gebruiker om twee getallen. Tel deze bij elkaar op en print het resultaat.
getal1 = None  # Verwacht dat de gebruiker zelf deze code uitvoert
getal2 = None  # Verwacht dat de gebruiker zelf deze code uitvoert
som = getal1 + getal2

# Hier gebruiken we komma's om het getal met de text samen te voegen
print("De som van de getallen is: ", som)
# Out:
# Voer het eerste getal in: 39
# Voer het tweede getal in: 20
# De som van de getallen is: 59

# %%
''' Opdracht 20: Dynamische begroeting'''
# TODO: Vraag de gebruiker om hun naam en print een begroeting met hun naam. Bijvoorbeeld: "Hallo, [naam]!"
naam = input("Wat is je naam? ")  # Verwacht dat de gebruiker zelf deze code uitvoert
# Out:
# Wat is je naam? Mees
# Hallo, Mees!

# %%
''' Opdracht 21: Oppervlakte berekenen'''
lengte = int(input('Wat is de lengte van het vierkant')) #LET OP: dit werkt niet goed in Jupyter Lite
breedte = 5

# TODO: Schrijf code die het oppervlakte van een vierkant als output geeft

# %%
'''
Snel klaar? Probeer deze opdrachten uit.
Bonus 1 - Schrijf code die vraagt naar het aantal kippen en koeien en het totaal aantal benen als output geeft.
Bonus 2 - Schrijf code die vraagt naar het aantal kippen en koeien en het totaal aantal benen en hoofden als output geeft.
'''
